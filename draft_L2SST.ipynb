# %% [raw]
# Look for L2 SST data files for specific dates and region using CMR, read and stack the files using s3fs, select a region of interest, plot the mean

# %%
import requests
import s3fs
from pprint import pprint
import xarray as xr
import numpy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy
from tqdm import tqdm

#to make big figures
plt.rcParams['figure.figsize'] = 12, 6

# %%
#select L2 data: 
dataset='podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0'
shortname='MODIS_T-JPL-L2P-v2019.0'

#timeframe of interest:
start_date = '2015-09-15T00:00:00Z'
end_date   = '2015-09-15T23:59:59Z'

#region of interest:
lonmin = -170.0
latmin = 65.0
lonmax = -120.0
latmax = 80.0

# %%
CMR_OPS = 'https://cmr.earthdata.nasa.gov/search'
url = f'{CMR_OPS}/{"collections"}'

# %%
provider = 'POCLOUD'
response = requests.get(url,
                        params={
                            'short_name': shortname,
                            'cloud_hosted': 'True',
                            'has_granules': 'True',
                            'provider': provider,
                            'page_size': 251,
                        },
                        headers={
                            'Accept': 'application/json'
                        }
                       )
collections = response.json()['feed']['entry']
for collection in collections:
    print(f'{collection["archive_center"]} {collection["dataset_id"]} {collection["id"]}')
# Out:
# NASA/JPL/PODAAC GHRSST Level 2P Global Sea Surface Skin Temperature from the Moderate Resolution Imaging Spectroradiometer (MODIS) on the NASA Terra satellite (GDS2) C1940475563-POCLOUD

# %%
concept_id='C1940475563-POCLOUD' #get the concept ID from earthdata website, clicking on the dataset, looking at the http link: https://search.earthdata.nasa.gov/search/granules/collection-details?p=C2075141524-POCLOUD&pg[0][v]=f&pg[0][gsk]=-start_date&q=L2&ff=Available%20from%20AWS%20Cloud&fi=ASCAT&fl=2%20-%20Geophys.%20Variables%2C%20Sensor%20Coordinates&tl=1637188235.263!3!!&m=8.456485070842092!-75.234375!1!1!0!0%2C2
url = f'{CMR_OPS}/{"granules"}'
spacebox=str(lonmin)+','+str(latmin)+','+str(lonmax)+','+str(latmax) #SW lon, SW lat, NE lon, NE lat
tempbox=f'{start_date},{end_date}'
response = requests.get(url, 
                        params={
                            'concept_id': concept_id,
                            'temporal': tempbox,
                            'bounding_box': spacebox,
                            'page_size': 228,
                            },
                        headers={
                            'Accept': 'application/json'
                            }
                       )
print(response.status_code)
print(response.headers['cmr-hits'])
# Out:
# 200
# 41

# %%
granules = response.json()['feed']['entry']
urls = []
for granule in granules:
    # print(granule['boxes'], granule['links'][0]['href'])
    urls.append(granule['links'][0]['href'])
pprint(urls[0])
pprint(urls[1])
# Out:
# 's3://podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20150915011500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'
# 's3://podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20150915011500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'

# %%
#s3fs
s3_cred_endpoint = {
    'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials'}

def get_temp_creds():
    temp_creds_url = s3_cred_endpoint['podaac']
    return requests.get(temp_creds_url).json()

temp_creds_req = get_temp_creds()

s3_client = s3fs.S3FileSystem(anon=False,key=temp_creds_req['accessKeyId'], secret=temp_creds_req['secretAccessKey'], token=temp_creds_req['sessionToken'])

# %%
ds = xr.open_dataset(s3_client.open('podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20150915011500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'), decode_cf=False) #issue when trying to open because of some CF conventions (?) so we add decode_cf=False
ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (nj: 2040, ni: 1354, time: 1)
# Coordinates:
#   * time                         (time) int32 1095124500
# Dimensions without coordinates: nj, ni
# Data variables: (12/14)
#     lat                          (nj, ni) float32 ...
#     lon                          (nj, ni) float32 ...
#     sea_surface_temperature      (time, nj, ni) int16 ...
#     sst_dtime                    (time, nj, ni) int16 ...
#     quality_level                (time, nj, ni) int8 ...
#     sses_bias                    (time, nj, ni) int8 ...
#     ...                           ...
#     sea_surface_temperature_4um  (time, nj, ni) int16 ...
#     quality_level_4um            (time, nj, ni) int8 ...
#     sses_bias_4um                (time, nj, ni) int8 ...
#     sses_standard_deviation_4um  (time, nj, ni) int8 ...
#     wind_speed                   (time, nj, ni) int8 ...
#     dt_analysis                  (time, nj, ni) int8 ...
# Attributes: (12/49)
#     Conventions:                [b'CF-1.7, ACDD-1.3']
#     title:                      [b'MODIS Terra L2P SST']
#     summary:                    [b'Sea surface temperature retrievals produce...
#     references:                 [b'GHRSST Data Processing Specification v2r5']
#     institution:                [b'NASA/JPL/OBPG/RSMAS']
#     history:                    [b'MODIS L2P created at JPL PO.DAAC']
#     ...                         ...
#     publisher_email:            [b'ghrsst-po@nceo.ac.uk']
#     processing_level:           [b'L2P']
#     cdm_data_type:              [b'swath']
#     startDirection:             [b'Ascending']
#     endDirection:               [b'Descending']
#     day_night_flag:             [b'Mixed']

# %%
# for file in urls:
#     ds = xr.open_dataset(s3_client.open(file), decode_cf=False) #issue when trying to open because of some CF conventions (?) so we add decode_cf=False
#     pprint(ds.sea_surface_temperature.shape)

# %%
fileset = [s3_client.open(file) for file in urls[0:10]] 
ds_stacked = xr.open_mfdataset(fileset, combine='by_coords', 
                               decode_cf=False,)
ds_stacked
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_125/1514118195.py in <module>
#       1 fileset = [s3_client.open(file) for file in urls[0:10]]
# ----> 2 ds_stacked = xr.open_mfdataset(fileset, combine='by_coords',
#       3                                decode_cf=False,)
#       4 ds_stacked
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     934             # Redo ordering from coordinates, ignoring how they were ordered
#     935             # previously
# --> 936             combined = combine_by_coords(
#     937                 datasets,
#     938                 compat=compat,
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/combine.py in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs, datasets)
#     973         concatenated_grouped_by_data_vars = []
#     974         for vars, datasets_with_same_vars in grouped_by_vars:
# --> 975             concatenated = _combine_single_variable_hypercube(
#     976                 list(datasets_with_same_vars),
#     977                 fill_value=fill_value,
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/combine.py in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     635
#     636     # Concatenate along all of concat_dims one by one to create single ds
# --> 637     concatenated = _combine_nd(
#     638         combined_ids,
#     639         concat_dims=concat_dims,
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/combine.py in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat, fill_value, join, combine_attrs)
#     232     # element of the tuple
#     233     for concat_dim in concat_dims:
# --> 234         combined_ids = _combine_all_along_first_dim(
#     235             combined_ids,
#     236             dim=concat_dim,
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/combine.py in _combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat, fill_value, join, combine_attrs)
#     268         combined_ids = dict(sorted(group))
#     269         datasets = combined_ids.values()
# --> 270         new_combined_ids[new_id] = _combine_1d(
#     271             datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#     272         )
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/combine.py in _combine_1d(datasets, concat_dim, compat, data_vars, coords, fill_value, join, combine_attrs)
#     291     if concat_dim is not None:
#     292         try:
# --> 293             combined = concat(
#     294                 datasets,
#     295                 dim=concat_dim,
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     240             f"objects, got {type(first_obj)}"
#     241         )
# --> 242     return f(
#     243         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     244     )
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     440     datasets = [ds.copy() for ds in datasets]
#     441     datasets = list(
# --> 442         align(*datasets, join=join, copy=False, exclude=[dim], fill_value=fill_value)
#     443     )
#     444
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     346     for dim, sizes in unlabeled_dim_sizes.items():
#     347         if dim not in all_indexes and len(sizes) > 1:
# --> 348             raise ValueError(
#     349                 f"arguments without labels along dimension {dim!r} cannot be "
#     350                 f"aligned because they have different dimension sizes: {sizes!r}"
#
# ValueError: arguments without labels along dimension 'nj' cannot be aligned because they have different dimension sizes: {2040, 2030}

# %%
def _open_mfdataset(urls: list): #from Jack, a simple concatenation with mfdataset was not working; have to put decode_cf=False because this dataset has a pb

    def _open_dataset(x):
        return xr.open_dataset(s3_client.open(x), 
                               decode_cf=False,
                               decode_coords=True,
                               mask_and_scale=True, )

    return xr.concat(list(map(lambda x: _open_dataset(x), tqdm(urls))), 
                     dim="time",
                     data_vars={"sea_surface_temperature"},#{"minimal"}, #['sea_surface_temperature'],
                     fill_value=numpy.nan, ).set_coords(['lat', 'lon'])
ds = _open_mfdataset(sorted(urls))

print(ds)
# Out:
# 100%|██████████| 41/41 [00:07<00:00,  5.62it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_961/3911181433.py in <module>
#      11                      data_vars={"sea_surface_temperature"},#['sea_surface_temperature'],
#      12                      fill_value=numpy.nan, ).set_coords(['lat', 'lon'])
# ---> 13 ds = _open_mfdataset(sorted(urls))
#      14
#      15 print(ds)
#
# /tmp/ipykernel_961/3911181433.py in _open_mfdataset(urls)
#       7                                mask_and_scale=True, )
#       8
# ----> 9     return xr.concat(list(map(lambda x: _open_dataset(x), tqdm(urls))),
#      10                      dim="time",
#      11                      data_vars={"sea_surface_temperature"},#['sea_surface_temperature'],
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     240             f"objects, got {type(first_obj)}"
#     241         )
# --> 242     return f(
#     243         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     244     )
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     440     datasets = [ds.copy() for ds in datasets]
#     441     datasets = list(
# --> 442         align(*datasets, join=join, copy=False, exclude=[dim], fill_value=fill_value)
#     443     )
#     444
#
# /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     346     for dim, sizes in unlabeled_dim_sizes.items():
#     347         if dim not in all_indexes and len(sizes) > 1:
# --> 348             raise ValueError(
#     349                 f"arguments without labels along dimension {dim!r} cannot be "
#     350                 f"aligned because they have different dimension sizes: {sizes!r}"
#
# ValueError: arguments without labels along dimension 'nj' cannot be aligned because they have different dimension sizes: {2040, 2030}

# %%
fileset = [s3_client.open(file) for file in urls] 
ds_stacked = xr.open_mfdataset(fileset,data_vars=['analysed_sst'],engine="h5netcdf",
    combine="by_coords",
    decode_coords=True,
    mask_and_scale=True,
    decode_cf=False,)
ds_stacked
# ds_stacked = xr.open_mfdataset(fileset, combine='by_coords')
# ds_stacked = xr.open_mfdataset(fileset,data_vars=['analysed_sst'],engine="h5netcdf",
#     combine="nested",
#     concat_dim="time",
#     decode_coords=True,
#     mask_and_scale=True,
#     decode_cf=False,)
